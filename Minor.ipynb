# %% [markdown]
# <a href="https://colab.research.google.com/github/Likithprem22/Campalin-Project/blob/main/Minor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
customers = pd.read_csv("/content/Ecommerce Customers.csv")
customers.plot(y=['Time on App','Time on Website'])
